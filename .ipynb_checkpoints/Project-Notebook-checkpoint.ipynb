# %% [markdown]
# ## PDC Project

# %%
import client
import channel_helper
import transmitter
import reciever

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Transmitter

# %%
# %%time 
transmitter.run()
# Out:
# Time for function waveform_former:
# 0.771099
# Frequency channel:
# 3926.7218543046356
# Time for function passband:
# 0.9723990000000002
# CPU times: user 1.63 s, sys: 114 ms, total: 1.75 s
# Wall time: 1.82 s

# %% [markdown]
# ### Channel Effect

# %%
#!python client.py --input_file=passband.txt --output_file=output.txt --srv_hostname=iscsrv72.epfl.ch --srv_port=80

# %% [markdown]
# ### Reciever

# %%
# %%time
reciever.run()
# Out:
# Time beginning:
# 0.028966999999999743
# Time for function inner_product:
# 0.055464000000000624
# Number of Correct Bits: 104/104
# Decoded recieved signal:
# ÿÿÿÿ testb 12
# Original text:
# ÿÿÿÿ testb 12
# CPU times: user 1.95 s, sys: 48.9 ms, total: 2 s
# Wall time: 1.19 s

# %% [markdown]
# ### Plots

# %%
def compute_array(datapath):
    f = open(datapath, 'r')
    array = f.read().split('\n')
    length = len(array)
    plot_array = array[:(length-1)]
    
    
    plot_array = list(map(float, plot_array))
    return plot_array

# %%
fig, ax = plt.subplots(2, figsize=(20,10))

passband = compute_array("passband.txt")
output = compute_array("output.txt")



ax[0].plot(passband)
ax[0].set_title('Passband')
ax[1].plot(output)
ax[1].set_title('Output')



plt.show()

# %% [markdown]
# ### Closer look

# %%
detail_lowpass = lowpass[35000:40000]
plt.figure(figsize=(30,10))
plt.plot(lowpass)
plt.show

# %% [markdown]
# ### TESTS

# %%
temp6 = compute_array("passband_fourier.txt")
#detail_pt = temp6[0:10000]

plt.figure(figsize=(40,10))
plt.plot(temp6)
plt.show
