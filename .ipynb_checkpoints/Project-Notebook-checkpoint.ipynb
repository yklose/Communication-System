# %% [markdown]
# ## PDC Project

# %%
import client
import channel_helper
import transmitter
import reciever

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Transmitter

# %%
# %%time 
transmitter.run()
# Out:
# Time for function waveform_former:
# 6.240453
# Frequency channel:
# 33729.0
# Time for function passband:
# 8.009327
# CPU times: user 13.4 s, sys: 868 ms, total: 14.3 s
# Wall time: 14.4 s

# %% [markdown]
# ### Channel Effect

# %%
#!python client.py --input_file=passband.txt --output_file=output.txt --srv_hostname=iscsrv72.epfl.ch --srv_port=80

# %% [markdown]
# ### Reciever

# %%
# %%time
reciever.run()
# Out:
# Time for function lowpass_filter:
# 35.114072
# Time for function inner_product:
# 4.745931999999996
# Number of Correct Bits: 136/136
# Decoded recieved signal:
# ÿe this is a test
# Original text:
# ÿe this is a test
# CPU times: user 36.7 s, sys: 3.16 s, total: 39.9 s
# Wall time: 38.5 s

# %% [markdown]
# ### Plots

# %%
def compute_array(datapath):
    f = open(datapath, 'r')
    array = f.read().split('\n')
    length = len(array)
    plot_array = array[:(length-1)]
    
    
    plot_array = list(map(float, plot_array))
    return plot_array

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,10))

waveform = compute_array("waveform.txt")
passband = compute_array("passband.txt")
filtered_noise = compute_array("filtered_noise.txt")
lowpass = compute_array("lowpass.txt")


ax[0][0].plot(waveform)
ax[0][0].set_title('Waveform')
ax[0][1].plot(passband)
ax[0][1].set_title('Passband')
ax[1][0].plot(filtered_noise)
ax[1][0].set_title('Filtered Noise')
ax[1][1].plot(lowpass)
ax[1][1].set_title('Lowpass Filter')


plt.show()

# %% [markdown]
# ### Closer look

# %%
detail_lowpass = lowpass[15500:16500]
plt.figure(figsize=(30,10))
plt.plot(lowpass)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### TESTS

# %%
temp1 = compute_array("passband.txt")
#detail_sinc = sinc[6700:7500]

plt.figure(figsize=(40,10))
plt.plot(temp1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
temp2 = compute_array("passband_after.txt")
#detail_phi = phi[900:1100]

plt.figure(figsize=(40,10))
plt.plot(temp2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
temp3 = compute_array("phi_before.txt")
#detail_temp3 = temp3[900:1100]

plt.figure(figsize=(40,10))
plt.plot(temp3)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
temp4 = compute_array("phi_testing.txt")
detail_temp4 = temp4[900:1100]

plt.figure(figsize=(40,10))
plt.plot(temp4)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
temp5 = compute_array("lowpass.txt")
#detail_pt = pt[0:400]

plt.figure(figsize=(40,10))
plt.plot(temp5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
temp6 = compute_array("cut_lowpass.txt")
#detail_pt = pt[0:400]

plt.figure(figsize=(40,10))
plt.plot(temp6)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Ask for shift in frequency domain and lowpass filter!
